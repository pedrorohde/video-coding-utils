# %%
from utils import *
from matplotlib import pyplot as plt

# %%
PATH = '../data/jpeg-ai/'

# %%
l_files = list_files(PATH, 'png')

# %%
l_files
# Out:
# ['../data/jpeg-ai/00016_TE_1744x2000.png',
#  '../data/jpeg-ai/00011_TE_1744x1160.png',
#  '../data/jpeg-ai/00001_TE_2096x1400.png',
#  '../data/jpeg-ai/00013_TE_1920x1280.png',
#  '../data/jpeg-ai/00004_TE_1808x1352.png',
#  '../data/jpeg-ai/00015_TE_3680x2456.png',
#  '../data/jpeg-ai/00005_TE_1336x872.png',
#  '../data/jpeg-ai/00012_TE_1512x2016.png',
#  '../data/jpeg-ai/00010_TE_2000x1128.png',
#  '../data/jpeg-ai/00009_TE_1976x1312.png',
#  '../data/jpeg-ai/00008_TE_1912x1272.png',
#  '../data/jpeg-ai/00006_TE_1544x1120.png',
#  '../data/jpeg-ai/00003_TE_1944x1296.png',
#  '../data/jpeg-ai/00014_TE_3680x2456.png',
#  '../data/jpeg-ai/00007_TE_1472x976.png',
#  '../data/jpeg-ai/00002_TE_2144x1424.png']

# %%
img = read_image(l_files[1])
img.shape
# Out:
# (1160, 1744, 3)

# %%
plt.imshow(img)
plt.show()

# %%
crop = crop_image(img, (100,100), (64,64))
crop.shape
# Out:
# (64, 64, 3)

# %%
plt.imshow(crop)
plt.show()

# %%
crops = n_random_crops(img, 3, (64,64))
crops.shape
# Out:
# (3, 64, 64, 3)

# %%
for i in range(crops.shape[0]):
    plt.imshow(crops[i,:,:,:])
    plt.show()

# %%
np_to_pil(crops[0,:,:,:])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F6CE40FCE50>

# %%
M = random_crops_from_dir(PATH, 10, (64,64))

# %%
# %timeit random_crops_from_dir(PATH, 10, (64,64))
# Out:
# 1.72 s ± 31.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
M.shape
# Out:
# (160, 64, 64, 3)
