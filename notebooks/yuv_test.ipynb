# %%
from utils import *
from matplotlib import pyplot as plt

# %%
filepath = '../data/H264_raw/test_Ionly.yuv'

# %%
width = 416
height = 240
size = (height, width)

# %%
# %timeit y = read_YUV420(filepath, size, 10, 'Y')
# Out:
# 197 µs ± 8.03 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit y = read_YUV420_multiframes(filepath, size, range(0,100,10), channel='Y')
# Out:
# 2.89 ms ± 42.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
y = read_YUV420_multiframes(filepath, size, [0, 700], channel='Y')

# %%
for i in range(2):
    plt.imshow(y[i,:,:])
    plt.show()

# %%
u = read_YUV420_multiframes(filepath, size, [0, 300], channel='cb')

# %%
for i in range(2):
    plt.imshow(u[i,:,:])
    plt.show()
